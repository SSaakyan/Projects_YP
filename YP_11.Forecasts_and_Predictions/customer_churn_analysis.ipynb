# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Импорт-данных-и-изучение-общей-информации" data-toc-modified-id="Импорт-данных-и-изучение-общей-информации-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Импорт данных и изучение общей информации</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Импорт библиотек</a></span></li><li><span><a href="#Импорт-данных-и-изучение-общей-информации" data-toc-modified-id="Импорт-данных-и-изучение-общей-информации-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Импорт данных и изучение общей информации</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-качества-признаков" data-toc-modified-id="Анализ-качества-признаков-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Анализ качества признаков</a></span></li><li><span><a href="#Формулировка-гипотез" data-toc-modified-id="Формулировка-гипотез-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Формулировка гипотез</a></span><ul class="toc-item"><li><span><a href="#Гистограммы-признаков" data-toc-modified-id="Гистограммы-признаков-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Гистограммы признаков</a></span></li><li><span><a href="#Матрица-корреляций" data-toc-modified-id="Матрица-корреляций-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Матрица корреляций</a></span></li></ul></li></ul></li><li><span><a href="#Построение-модели-прогнозирования-оттока-клиентов" data-toc-modified-id="Построение-модели-прогнозирования-оттока-клиентов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Построение модели прогнозирования оттока клиентов</a></span></li><li><span><a href="#Класстеризация-клиентов" data-toc-modified-id="Класстеризация-клиентов-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Класстеризация клиентов</a></span><ul class="toc-item"><li><span><a href="#Агломеративная-иерархическая-кластеризация" data-toc-modified-id="Агломеративная-иерархическая-кластеризация-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Агломеративная иерархическая кластеризация</a></span></li><li><span><a href="#K-Means" data-toc-modified-id="K-Means-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>K-Means</a></span></li></ul></li><li><span><a href="#Выводы-и-базовые-рекомендации-по-работе-с-клиентами" data-toc-modified-id="Выводы-и-базовые-рекомендации-по-работе-с-клиентами-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы и базовые рекомендации по работе с клиентами</a></span></li></ul></div>

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Заказчик подготовил данные, которые содержат данные на месяц до оттока и факт оттока на определённый месяц. Набор данных включает следующие поля:
# - *Churn* — факт оттока в текущем месяце;
# - Текущие поля в датасете:
#   * Данные клиента за предыдущий до проверки факта оттока месяц:
#       - *gender* — пол;
#       - *Near_Location* — проживание или работа в районе, где находится фитнес-центр;
#       - *Partner* — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на                         абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента);
#       - *Promo_friends* — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при                               оплате первого абонемента);
#       - *Phone* — наличие контактного телефона;
#       - *Age* — возраст;
#       - *Lifetime* — время с момента первого обращения в фитнес-центр (в месяцах).
# - Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
#    - *Contract_period* — длительность текущего действующего абонемента (месяц, 3 месяца, 6 месяцев, год);
#    - *Month_to_end_contract* — срок до окончания текущего действующего абонемента (в месяцах);
#    - *Group_visits* — факт посещения групповых занятий;
#    - *Avg_class_frequency_total* — средняя частота посещений в неделю за все время с начала действия абонемента;
#    - *Avg_class_frequency_current_month* — средняя частота посещений в неделю за предыдущий месяц;
#    - *Avg_additional_charges_total* — суммарная выручка от других услуг фитнес-центра: кафе, спорт-товары, косметический и                                           массажный салон.

# %% [markdown]
# <font size = 4> **План работы** </font>

# %% [markdown]
# 1. Импорт данных и изучение общей информации.
# 2. Исследовательский анализ данных.
# 3. Построение модели прогнозирования оттока клиентов.
# 4. Класстеризация клиентов.
# 5. Выводы и базовые рекомендации по работе с клиентами.

# %% [markdown]
# ## Импорт данных и изучение общей информации

# %% [markdown]
# ### Импорт библиотек

# %%
import pandas as pd
import numpy as np

import math

import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, precision_score, recall_score

from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans

from IPython.display import display

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Импорт данных и изучение общей информации

# %%
df = pd.read_csv('/datasets/gym_churn.csv')

# %%
# Посмотрим на данные и на общую информацию по ним:
display(df.head(10))
df.info()
print('Размер датасета:', df.shape)
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
# 5       1              1        0              0      1                1
# 6       1              1        1              1      0                6
# 7       0              1        0              0      1                1
# 8       1              1        1              1      1                1
# 9       0              1        0              0      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# ...

# %% [markdown]
# **Вывод:** Есть данные по 4000 клиентам, пропущенных значений нет, тип данных в столбце Month_to_end_contract переведём в целочисленный, в датасете - одна целевая переменная - бинарная величина и 13 возможных признаков числового типа (6 из них бинарные величины).

# %%
#изменим тип данных в столбце Month_to_end_contract на целочисленный
df['Month_to_end_contract'] = df['Month_to_end_contract'].astype(int)

# %%
#для удобства приведем все названия столбцов к нижнему регистру:
df.columns = df.columns.str.lower()

# %%
# Проверим данные на дубликаты:
print('Количество дубликатов: ', df.duplicated().sum())
# Out:
# Количество дубликатов:  0

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Анализ качества признаков

# %% [markdown]
# Выяснили, что в датасете нет пропущенных значений, все признаки числового типа, у целевой переменной нет временной структуры. Теперь посмотрим на статистику признаков.

# %%
# Посмотрим на статистику признаков и целевой переменной
display(df.describe().T)
# Out:
#                                     count        mean        std        min  \
# gender                             4000.0    0.510250   0.499957   0.000000
# near_location                      4000.0    0.845250   0.361711   0.000000
# partner                            4000.0    0.486750   0.499887   0.000000
# promo_friends                      4000.0    0.308500   0.461932   0.000000
# phone                              4000.0    0.903500   0.295313   0.000000
# contract_period                    4000.0    4.681250   4.549706   1.000000
# group_visits                       4000.0    0.412250   0.492301   0.000000
# age                                4000.0   29.184250   3.258367  18.000000
# avg_additional_charges_total       4000.0  146.943728  96.355602   0.148205
# month_to_end_contract              4000.0    4.322750   4.191297   1.000000
# lifetime                           4000.0    3.724750   3.749267   0.000000
# ...

# %% [markdown]
# **Вывод:**
# 1. Доля оттока - 26.5%
# 2. Шесть признаков - бинарные величины, наибольший разброс в данных - по признаку avg_additional_charges_total.
# 3. Распределение по полу примерно одинаковое
# 4. Большинство клиентов живут или работают в районе, где находится клуб
# 5. Около половины клиентов - сотрудники компаний-партнёров клуба
# 6. Около трети клиентов пришли по программе "приведи друга" (30%)
# 7. Почти все клиенты предоставили свои номера телефонов (90%)
# 8. Средняя продолжительность абонемента - 4,6 мес.
# 9. 41% клиентов посещал групповые занятия
# 10. Средний возраст клиентов - 29 лет
# 11. В среднем расходы клиенты на другие услуги фитнес-центра - 146.94
# 12. В среднем до конца абонемента оастается 4.3 мес.
# 13. Среднее время с момента первого обращения в фитнес-центр - 3.7 мес.
# 14. Средняя частота посещений в неделю за все время с начала действия абонемента - 1.87
# 15. Средняя частота посещений в неделю за предыдущий месяц - 1.76

# %%
#Взглянем на средние значения признаков в зависимости от факта ухода/не ухода клиента:
display(df.groupby('churn').mean().T)
# Out:
# churn                                       0           1
# gender                               0.510037    0.510839
# near_location                        0.873086    0.768143
# partner                              0.534195    0.355325
# promo_friends                        0.353522    0.183789
# phone                                0.903709    0.902922
# contract_period                      5.747193    1.728558
# group_visits                         0.464103    0.268615
# age                                 29.976523   26.989632
# avg_additional_charges_total       158.445715  115.082899
# month_to_end_contract                5.283089    1.662582
# lifetime                             4.711807    0.990575
# avg_class_frequency_total            2.024876    1.474995
# avg_class_frequency_current_month    2.027882    1.044546

# %% [markdown]
# **Выводы:**
# 1. В двух группах в среднем почти нет разницы между полом клиента, наличием телефона
# 2. Вероятность нахождения клуба в районе дома/работы у клиентов, которые остались, выше, чем у тех, кто ушёл
# 3. Среди клиентов, которые остались, чаще встречаются сотрудники компаний-партнёров клуба и клиенты, пришедшие по акции "приведи друга", чем среди ушедших клиентов.
# 4. У клиентов, которые остались, в среднем договора не на один месяц (соответственно у них выше средний lifetime и срок до окончания договора), они старше и пользуются другими услугами чаще.
# 5. Средний срок договора у ушедших клиентов - 1.72 мес. (в основном эти клиенты покупают абонемент на месяц)
# 6. Клиенты, которые остались, в среднем чаще посещают клуб (в месяц - почти в два раза)

# %% [markdown]
# ### Формулировка гипотез

# %% [markdown]
# #### Гистограммы признаков

# %% [markdown]
# Построим гистограммы признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток).

# %%
# вспомогательная функция для отрисовки гистограмм:
def histogram(feature):
    fig, ax = plt.subplots(1 ,2, figsize=(14,4))
    sns.distplot(df.query('churn == 1')[feature],bins=10, ax=ax[0])
    sns.distplot(df.query('churn == 0')[feature],bins=10, ax=ax[1])
    fig.suptitle('Гистограмма '+ feature, size=15)
    ax[0].set(title='Отток')
    ax[1].set(title='Оставшиеся')
    ax[0].set(ylabel='Частота')
    ax[1].set(ylabel='Частота')
    return plt.show()

# %%
# посмотрим на гистограммы:
for feature in df.drop('churn', axis=1).columns:
    histogram(feature)

# %% [markdown]
# **Выводы:**
# 1. Графики подтверждают выводы, сделанные выше.
# 2. Аномалий не выявлено.

# %% [markdown]
# #### Матрица корреляций

# %%
#Построим тепловую карту на основе матрицы корреляций
plt.figure(figsize=(16,8))
plt.title("Матрица корреляций",size=18)
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# **Вывод:**
# 1. По матрице корреляций видно, что у целевой переменной обратная зависимость с признаками:
#    * "lifetime" (т.е. если клиент долго ходит в фитнес центр, то он скорее останется, чем уйдет),
#    - "возраст",
#    - "средняя частота посещений в неделю за предыдущий месяц",
# 2. Также можно отметить мультиколлиниарность признаков:
#    * "средняя частота посещений в неделю за предыдущий месяц" и "средняя частота посещений в неделю за все время с начала             действия абонемента",
#    - "длительность текущего действующего абонемента" и "срок до окончания текущего действующего абонемента"

# %% [markdown]
# ## Построение модели прогнозирования оттока клиентов

# %% [markdown]
# <font size = 3> **1. Разбиваем выборку на обучающую и валидационную** </font>

# %%
# Разбиваем данные на признаки и целевую переменную:
X = df.drop('churn', axis=1)
y = df['churn']

# %% [markdown]
# Т.к. у нас достаточно много наблюдений и временная структура не важна, разделим выборку в пропорции 70:30 случайным способом

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# <font size = 3> **2. Применяем стандартизацию** </font>

# %%
# Обучаем и применяем стандартизацию на обучающей выборке:
scaler = StandardScaler()
X_train_st = scaler.fit_transform(X_train)

# %%
# Применяем "стандартизатор" к валидационной выборке:
X_test_st = scaler.transform(X_test)

# %% [markdown]
# <font size = 3> **3. Строим модели и рассчитываем метрики** </font>

# %% [markdown]
# Для рассчёта прогноза будем использовать две модели: логистическую регрессию и случайный лес

# %%
# напишим функцию для обучения модели и рассчёта метрик:
def predictions(m, m_name, X_train, y_train, X_test, y_test):
    model = m
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print('Метрики для модели ', m_name)
    print('Accuracy: {:.3f}'.format(accuracy_score(y_test,y_pred)))
    print('Precision: {:.3f}'.format(precision_score(y_test,y_pred)))
    print('Recall: {:.3f}'.format(recall_score(y_test,y_pred)))

# %%
# Рассчитаем метрики для двух моделей с учётом стандартизации признаков:
predictions(LogisticRegression(random_state=0), '"Логистическая регрессия": ', X_train_st, y_train, X_test_st, y_test)
predictions(
    RandomForestClassifier(n_estimators = 100, random_state=0),
    '"Случайный лес": ',
    X_train_st,
    y_train,
    X_test_st,
    y_test
)
# Out:
# Метрики для модели  "Логистическая регрессия":
# Accuracy: 0.924
# Precision: 0.871
# Recall: 0.835
# Метрики для модели  "Случайный лес":
# Accuracy: 0.917
# Precision: 0.853
# Recall: 0.826

# %% [markdown]
# **Вывод:** По всем метрикам логистическая регрессия показала себя лучше.

# %% [markdown]
# <font size = 3> **4. Посмотрим на важность признаков** </font>

# %%
# Обучим финальную модель и сделаем прогноз:
f_m = LogisticRegression(random_state=0)
f_m.fit(X_train_st, y_train)
y_pred = f_m.predict(X_test_st)

# %%
y_pred_coef = pd.DataFrame(f_m.coef_.T, X.columns).reset_index()
y_pred_coef.columns = ['Признак','Коэффициент']
print(y_pred_coef.sort_values(by='Коэффициент', ascending=False))
# Out:
#                               Признак  Коэффициент
# 11          avg_class_frequency_total     3.080793
# 4                               phone     0.010189
# 0                              gender    -0.034509
# 1                       near_location    -0.080655
# 2                             partner    -0.091385
# 3                       promo_friends    -0.295946
# 6                        group_visits    -0.434112
# 9               month_to_end_contract    -0.523419
# 8        avg_additional_charges_total    -0.526682
# 5                     contract_period    -0.787573
# 7                                 age    -1.104626
# 10                           lifetime    -3.742879
# 12  avg_class_frequency_current_month    -4.200553

# %% [markdown]
# **Вывод:** Наличие телефона практически не важно для нашего прогноза, а вот частота посещения и lifetime - важные признаки.

# %% [markdown]
# ## Класстеризация клиентов

# %% [markdown]
# ### Агломеративная иерархическая кластеризация

# %%
#Стандартизируем данные признаков:
x_sc = scaler.fit_transform(X)

# %%
#Построим матрицу расстояний:
linked = linkage(x_sc, method = 'ward')

# %%
#нарисуем дендрограмму:
plt.figure(figsize=(15,10))
plt.title('Иерархическая кластеризация')
dendrogram(linked, orientation='top')
plt.show()

# %% [markdown]
# **Вывод:** на основе дендрограммы 4 -  оптимальное число кластеров.

# %% [markdown]
# ### K-Means

# %% [markdown]
# Возьмём число кластеров равным 5.

# %%
km = KMeans(n_clusters = 5, random_state=0)

# %%
#прогнозируем кластеры для наблюдений
labels = km.fit_predict(x_sc)

# %%
#сохраним метки кластера в первоначальный датасет:
df['cluster_km'] = labels

# %%
#Посмотрим на размеры кластеров:
print(df.groupby(['cluster_km'])['gender'].count())
# Out:
# cluster_km
# 0    1010
# 1     385
# 2     505
# 3    1262
# 4     838
# Name: gender, dtype: int64

# %%
#выведем статистику по средним значениям признаков по кластеру:
print(df.groupby(['cluster_km']).mean().T)
# Out:
# cluster_km                                  0           1           2  \
# gender                               0.502970    0.522078    0.495050
# near_location                        0.959406    0.862338    0.000000
# partner                              0.783168    0.470130    0.463366
# promo_friends                        0.574257    0.306494    0.079208
# phone                                1.000000    0.000000    1.000000
# contract_period                     10.889109    4.787013    2.352475
# group_visits                         0.542574    0.425974    0.215842
# age                                 29.982178   29.301299   28.477228
# avg_additional_charges_total       160.761016  143.957664  135.457501
# month_to_end_contract                9.954455    4.475325    2.198020
# lifetime                             4.736634    3.924675    2.809901
# avg_class_frequency_total            1.982055    1.847220    1.660461
# ...

# %% [markdown]
# **Выводы:**
# - **Кластер 0**:
#         - Доля оттока - 2.8% - самая низкая
#         - Средний возраст - 29.98 лет
#         - Самые длительные по сроку действия абонементы в данном кластере
#         - В основном живут и работают рядом с клубом
#         - Средний lifetime - 4.73 мес.
#         - В среднем посещают клуб 2 раза в неделю (за все время действия абонемента)
#         - Больше всего сотрудников компаний-партнёров (78%) и клиентов, пришедших по акции "приведи друга" (57%)
#         - Высокий средний уровень расходов на другие услуги фитнес-центра (160.7)
#         - Все клиенты предоставили номер контактного телефона
#         - Групповые занятия посещали 54% клиентов
# - **Кластер 1**:
#         - Доля оттока - 26.8%
#         - Средний возраст - 29.3 лет
#         - Средний lifetime - 3.92 мес.
#         - Ни один клиент не предоставил номер контактного телефона
#         - Доля сотрудников компаний-партнёров - 47%, и доля клиентов, пришедших по акции "приведи друга" - 30.6%
#         - В основном живут и работают рядом с клубом
#         - В данном кластере меньше всего клиентов.
# - **Кластер 2**:
#         - Доля оттока - 44%
#         - Средний возраст - 28.47 лет
#         - Средний lifetime - 2.8 мес.
#         - Все клиенты предоставили номер контактного телефона
#         - Самая низкая доля клиентов, пришедших по акции "приведи друга". -7.9%
#         - Клиенты живут и работаю не рядом с клубом
# - **Кластер 3**:
#         - Доля оттока - 51.4% - самая большая
#         - Средний возраст - 28.17 лет - самая "молодая" группа
#         - Все клиенты живут или работаю рядом с клубом
#         - Основная масса абонементов - на 1 месяц
#         - Самые низкие дополнительные расходы на другие услуги финтес-центра
#         - Самый короткий lifetime (новички)
#         - Реже всех посещают спортклуб
#         - К данному кластеру отнесено больше всего клиентов
# - **Кластер 4**:
#         - Доля оттока - 6.8%
#         - Средний возраст - 30.12 лет - самые "взрослые"
#         - Чаще всего посещают клуб в неделю
#         - Средний lifetime - 4.89 мес.
#         - Самый большой уровень дополнительных расходов на другие услуги фитнес-центра
#         - Борльшая часть живёт или работает рядом с клубом
#         - В основном небольшие сроки абонементов
#         - Групповые занятия посещали 47% клиентов

# %% [markdown]
# Построим распределения признаков для кластеров

# %%
df1 = df.drop('churn', axis=1)
for value in [0, 1, 2, 3, 4]:
  df1[df1['cluster_km']==value].drop('cluster_km', axis=1).hist(figsize=(17,10))
  plt.suptitle('\n Распределение признаков для кластера {}'.format(value), fontsize = 15)
  plt.show()

# %% [markdown]
# **Выводы:**
# - **Кластер 0**:
#         - Доля оттока - 2.8% - самая низкая
#         - Средний возраст - 29.98 лет
#         - Абонементы на 6 и 12 месяцев
#         - В основном живут и работают рядом с клубом
#         - Средний lifetime - 4.73 мес.
#         - В среднем посещают клуб 2 раза в неделю (за все время действия абонемента)
#         - Больше всего сотрудников компаний-партнёров (78%) и клиентов, пришедших по акции "приведи друга" (57%)
#         - Высокий средний уровень расходов на другие услуги фитнес-центра (160.7)
#         - Все клиенты предоставили номер контактного телефона
#         - Групповые занятия посещали 54% клиентов
# - **Кластер 1**:
#         - Доля оттока - 26.8%
#         - Средний возраст - 29.3 лет
#         - Средний lifetime - 3.92 мес.
#         - Ни один клиент не предоставил номер контактного телефона
#         - Доля сотрудников компаний-партнёров - 47%, и доля клиентов, пришедших по акции "приведи друга" - 30.6%
#         - Чаще всего берут абонемент на 1 месяц, но также покупают абонементы и на 6 и на 12 месяцев
#         - В основном живут и работают рядом с клубом
#         - В данном кластере меньше всего клиентов.
# - **Кластер 2**:
#         - Доля оттока - 44%
#         - Средний возраст - 28.47 лет
#         - Средний lifetime - 2.8 мес.
#         - Все клиенты предоставили номер контактного телефона
#         - Самая низкая доля клиентов, пришедших по акции "приведи друга". -7.9%
#         - Клиенты живут и работают не рядом с клубом
#         - В основном клиенты берут абонемент на 1 месяц, в меньшей степени -на 6 мес. и очень маленькая часть - на 12 мес.
# - **Кластер 3**:
#         - Доля оттока - 51.4% - самая большая
#         - Средний возраст - 28.17 лет - самая "молодая" группа
#         - Все клиенты живут или работаю рядом с клубом
#         - Основная масса абонементов - на 1 месяц, на 12 месяцев нет вовсе
#         - Самые низкие дополнительные расходы на другие услуги финтес-центра
#         - Самый короткий lifetime (новички)
#         - Реже всех посещают спортклуб
#         - К данному кластеру отнесено больше всего клиентов
# - **Кластер 4**:
#         - Доля оттока - 6.8%
#         - Средний возраст - 30.12 лет - самые "взрослые"
#         - Чаще всего посещают клуб в неделю
#         - В основном клиенты - "старожилы" клуба.
#         - Самый большой уровень дополнительных расходов на другие услуги фитнес-центра
#         - Борльшая часть живёт или работает рядом с клубом
#         - В большинстве своем абонементы - на 1 мес., около трети - на 6 мес.и небольшая часть ь- на 12 мес.
#         - Групповые занятия посещали 47% клиентов

# %% [markdown]
# ## Выводы и базовые рекомендации по работе с клиентами

# %% [markdown]
# <font size = 4> **Выводы** </font>
# 1. Анализ проведён на основе  4 000 наблюдений, в данных нет пропусков, дубликатов. Целевая переменная - бинарная величина и 13    признаков числового типа (6 из них бинарные величины).
# 2. Иредварительный анализ данных показал, что в общем датасете:
#     - Доля оттока в данных - 26.5%
#     - В данных примерно поровну мужчин и женщин
#     -  Большинство клиентов живут или работают в районе, где находится клуб
#     -  Около половины клиентов - сотрудники компаний-партнёров клуба
#     -  Около трети клиентов пришли по программе "приведи друга" (30%)
#     -  Почти все клиенты предоставили свои номера телефонов (90%)
#     -  Средняя продолжительность абонемента - 4,6 мес.
#     -  41% клиентов посещал групповые занятия
#     -  Средний возраст клиентов - 29 лет
#     -  В среднем расходы клиенты на другие услуги фитнес-центра - 146.94
#     -  В среднем до конца абонемента оастается 4.3 мес.
#     -  Среднее время с момента первого обращения в фитнес-центр - 3.7 мес.
#     -  Средняя частота посещений в неделю за все время с начала действия абонемента - 1.87 раз
#     -  Средняя частота посещений в неделю за предыдущий месяц - 1.76 раз
#     -  На основе матрицы корреляций выявлено, что у целевой переменной просматривается обратная зависимость с признаками:
#             - "lifetime" (т.е. если клиент долго ходит в фитнес центр, то он скорее останется, чем уйдет),
#             - "возраст",
#             - "средняя частота посещений в неделю за предыдущий месяц",
#     -  Также можно отметить мультиколлиниарность признаков:
#             - "средняя частота посещений в неделю за предыдущий месяц" и "средняя частота посещений в неделю за все время с                    начала действия абонемента",
#             - "длительность текущего действующего абонемента" и "срок до окончания текущего действующего абонемента"
# 3. На основе анализа по группам "ушедших" и "оставшихся" выяснили:
#     -  В двух группах в среднем почти нет разницы между полом клиента, наличием телефона
#     -  Вероятность нахождения клуба в районе дома/работы у клиентов, которые остались, выше, чем у тех, кто ушёл
#     -  Среди клиентов, которые остались, чаще встречаются сотрудники компаний-партнёров клуба и клиенты, пришедшие по акции            "приведи друга", чем среди ушедших клиентов.
#     -  У клиентов, которые остались, в среднем договора не на один месяц (соответственно у них выше средний lifetime и срок до        окончания договора), они старше и пользуются другими услугами чаще.
#     -  Средний срок договора у ушедших клиентов - 1.72 мес. (в основном эти клиенты покупают абонемент на месяц)
#     -  Клиенты, которые остались, в среднем чаще посещают клуб (в месяц - почти в два раза)
#     -  Аномалий не выявлено.
# 4. На основе метрик лучшей для прогнозирования оказалась модель логистической регрессии.
# 5. Самые важные признаки логистической регрессии - частота посещения и lifetime, наличие телефона - практического никакого влияния не имеет.
# 6. На основе дендрограммы 4 -  оптимальное число кластеров.
# 7. С помощью алгоритма K-Means сгруппировали клиентов в 5 кластеров:
#     - **Кластер 0**:
#         - Доля оттока - 2.8% - самая низкая
#         - Средний возраст - 29.98 лет
#         - Абонементы на 6 и 12 месяцев
#         - В основном живут и работают рядом с клубом
#         - Средний lifetime - 4.73 мес.
#         - В среднем посещают клуб 2 раза в неделю (за все время действия абонемента)
#         - Больше всего сотрудников компаний-партнёров (78%) и клиентов, пришедших по акции "приведи друга" (57%)
#         - Высокий средний уровень расходов на другие услуги фитнес-центра (160.7)
#         - Все клиенты предоставили номер контактного телефона
#         - Групповые занятия посещали 54% клиентов
#     - **Кластер 1**:
#         - Доля оттока - 26.8%
#         - Средний возраст - 29.3 лет
#         - Средний lifetime - 3.92 мес.
#         - Ни один клиент не предоставил номер контактного телефона
#         - Доля сотрудников компаний-партнёров - 47%, и доля клиентов, пришедших по акции "приведи друга" - 30.6%
#         - Чаще всего берут абонемент на 1 месяц, но также покупают абонементы и на 6 и на 12 месяцев
#         - В основном живут и работают рядом с клубом
#         - В данном кластере меньше всего клиентов.
#     - **Кластер 2**:
#         - Доля оттока - 44%
#         - Средний возраст - 28.47 лет
#         - Средний lifetime - 2.8 мес.
#         - Все клиенты предоставили номер контактного телефона
#         - Самая низкая доля клиентов, пришедших по акции "приведи друга". -7.9%
#         - Клиенты живут и работают не рядом с клубом
#         - В основном клиенты берут абонемент на 1 месяц, в меньшей степени -на 6 мес. и очень маленькая часть - на 12 мес.
#     - **Кластер 3**:
#         - Доля оттока - 51.4% - самая большая
#         - Средний возраст - 28.17 лет - самая "молодая" группа
#         - Все клиенты живут или работаю рядом с клубом
#         - Основная масса абонементов - на 1 месяц, на 12 месяцев не совсем
#         - Самые низкие дополнительные расходы на другие услуги финтес-центра
#         - Самый короткий lifetime (новички)
#         - Реже всех посещают спортклуб
#         - К данному кластеру отнесено больше всего клиентов
#     - **Кластер 4**:
#         - Доля оттока - 6.8%
#         - Средний возраст - 30.12 лет - самые "взрослые"
#         - Чаще всего посещают клуб в неделю
#         - В основном клиенты - "старожилы" клуба.
#         - Самый большой уровень дополнительных расходов на другие услуги фитнес-центра
#         - Борльшая часть живёт или работает рядом с клубом
#         - В большинстве своем абонементы - на 1 мес., около трети - на 6 мес.и небольшая часть ь- на 12 мес.
#         - Групповые занятия посещали 47% клиентов
# 8. Клиенты кластеров 2,3 склонны к оттоку, а клиенты кластеров 0,4 - самые "надёжные":

# %% [markdown]
# <font size = 4> **Базовые рекомендации** </font>

# %% [markdown]
# 1. Чем дольше и чаще клиент ходит, тем больше вероятность, что он останется. Поэтому стоит обратить внимание на:
#      - увеличение продаж годовых абонементов - сделать их более привлекательными, доступными (например, с помощью                            рассрочек, привлекательных акций на годовые абонементы или при приближении срока окончания абонемента                          предлагать продление с хорошей скидкой);
#      - увеличение частоты посещения фитнес-центра (например, бонусы за количество посещений).
# 2. Разнообразить групповые программы (особенно ориентированных на "молодое" поколение)
